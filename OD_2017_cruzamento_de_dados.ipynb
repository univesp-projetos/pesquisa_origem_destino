# %%
import pandas as pd

# %%
# Abre os dois arquivos, para poder fazer o JOIN
file_path_ibge = 'OD_2017_fator_de_comparação_IBGE.xlsx'
df_ibge = pd.read_excel(file_path_ibge, engine='openpyxl')
df_ibge.head()
# Out:
#     ID_PESS  IDADE GRUPO ETÁRIO     2017     2018     2019     2020     2021  \
# 0  10001101     59        55-59  2491800  2541542  2588005  2632224  2674059
# 1  10347101     56        55-59  2491800  2541542  2588005  2632224  2674059
# 2  10349101     56        55-59  2491800  2541542  2588005  2632224  2674059
# 3  10680101     59        55-59  2491800  2541542  2588005  2632224  2674059
# 4  20497101     58        55-59  2491800  2541542  2588005  2632224  2674059
#
#       2022     2023  ...     2059     2060  FATOR_2017_2023  FATOR_2017_2025  \
# 0  2713763  2751343  ...  3157523  3111544         1.104159         1.131573
# 1  2713763  2751343  ...  3157523  3111544         1.104159         1.131573
# 2  2713763  2751343  ...  3157523  3111544         1.104159         1.131573
# 3  2713763  2751343  ...  3157523  3111544         1.104159         1.131573
# 4  2713763  2751343  ...  3157523  3111544         1.104159         1.131573
#
# ...

# %%
file_path_pesquisa = 'OD_2017.xlsx'
df_pesquisa = pd.read_excel(file_path_pesquisa, engine='openpyxl')
df_pesquisa.head()
# Out:
#    ZONA - Zona do Domicílio  MUNI_DOM - Município de Domicílio  \
# 0                         1                                 36
# 1                         1                                 36
# 2                         1                                 36
# 3                         1                                 36
# 4                         1                                 36
#
#    CO_DOM_X - Coordenada X Domicílio  CO_DOM_Y - Coordenada Y Domicílio  \
# 0                             333743                            7394463
# 1                             333743                            7394463
# 2                             333743                            7394463
# 3                             333743                            7394463
# 4                             333743                            7394463
#
#    ID_DOM - Identifica Domicílio  \
# 0                          10001
# 1                          10001
# 2                          10001
# ...

# %%
df = df_pesquisa.merge(df_ibge, left_on='ID_PESS - Identifica Pessoa', right_on='ID_PESS')
df.head()
# Out:
#    ZONA - Zona do Domicílio  MUNI_DOM - Município de Domicílio  \
# 0                         1                                 36
# 1                         1                                 36
# 2                         1                                 36
# 3                         1                                 36
# 4                         1                                 36
#
#    CO_DOM_X - Coordenada X Domicílio  CO_DOM_Y - Coordenada Y Domicílio  \
# 0                             333743                            7394463
# 1                             333743                            7394463
# 2                             333743                            7394463
# 3                             333743                            7394463
# 4                             333743                            7394463
#
#    ID_DOM - Identifica Domicílio  \
# 0                          10001
# 1                          10001
# 2                          10001
# ...

# %%
df['FE_PESS - Fator de Expansão da Pessoa'].sum()
# Out:
# 20821670.871776994

# %%
# cria as novas colunas aplicando o fator de expansão pela projeção DO IBGE
df['FE_PESS_2023'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2023']
df['FE_PESS_2025'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2025']
df['FE_PESS_2035'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2035']
df['FE_PESS_2040'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2040']
df['FE_PESS_2045'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2045']
df['FE_PESS_2050'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2050']
df['FE_PESS_2055'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2055']
df['FE_PESS_2060'] = df['FE_PESS - Fator de Expansão da Pessoa'] * df['FATOR_2017_2060']
df.head()
# Out:
#    ZONA - Zona do Domicílio  MUNI_DOM - Município de Domicílio  \
# 0                         1                                 36
# 1                         1                                 36
# 2                         1                                 36
# 3                         1                                 36
# 4                         1                                 36
#
#    CO_DOM_X - Coordenada X Domicílio  CO_DOM_Y - Coordenada Y Domicílio  \
# 0                             333743                            7394463
# 1                             333743                            7394463
# 2                             333743                            7394463
# 3                             333743                            7394463
# 4                             333743                            7394463
#
#    ID_DOM - Identifica Domicílio  \
# 0                          10001
# 1                          10001
# 2                          10001
# ...

# %%
# cria as novas colunas aplicando o fator de expansão da viagem multiplicado pela projeção DO IBGE
df['FE_VIA_2023'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2023']
df['FE_VIA_2025'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2025']
df['FE_VIA_2035'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2035']
df['FE_VIA_2040'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2040']
df['FE_VIA_2045'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2045']
df['FE_VIA_2050'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2050']
df['FE_VIA_2055'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2055']
df['FE_VIA_2060'] = df['FE_VIA - Fator de Expansão da Viagem'] * df['FATOR_2017_2060']
df.head()
# Out:
#    ZONA - Zona do Domicílio  MUNI_DOM - Município de Domicílio  \
# 0                         1                                 36
# 1                         1                                 36
# 2                         1                                 36
# 3                         1                                 36
# 4                         1                                 36
#
#    CO_DOM_X - Coordenada X Domicílio  CO_DOM_Y - Coordenada Y Domicílio  \
# 0                             333743                            7394463
# 1                             333743                            7394463
# 2                             333743                            7394463
# 3                             333743                            7394463
# 4                             333743                            7394463
#
#    ID_DOM - Identifica Domicílio  \
# 0                          10001
# 1                          10001
# 2                          10001
# ...

# %%
df.to_excel(f'OD_2017_E_IBGE.xlsx', index=False)
print('Arquivo salvo com sucesso')
# Out:
# Arquivo salvo com sucesso
