# %%
import pandas as pd

# %%
# Abre o arquivo utilizado anteriormente, que possui os dados da 
# Pesquisa Destino 2017 com as colunas tratadas + os fatores de 
# crescimento populacional do IBGE
file_path = 'OD_2017_E_IBGE.csv'
df = pd.read_csv(file_path, low_memory=False)
df.head()
# Out:
#    ZONA - Zona do Domicílio  MUNI_DOM - Município de Domicílio  \
# 0                         1                                 36
# 1                         1                                 36
# 2                         1                                 36
# 3                         1                                 36
# 4                         1                                 36
#
#    CO_DOM_X - Coordenada X Domicílio  CO_DOM_Y - Coordenada Y Domicílio  \
# 0                             333743                            7394463
# 1                             333743                            7394463
# 2                             333743                            7394463
# 3                             333743                            7394463
# 4                             333743                            7394463
#
#    ID_DOM - Identifica Domicílio  \
# 0                          10001
# 1                          10001
# 2                          10001
# 3                          10001
# 4                          10001
#
#    F_DOM - Identifica Primeiro Registro do Domicílio  \
# 0                                                  1
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    FE_DOM - Fator de Expansão do Domicílio  DOM - Número do Domicílio  \
# 0                                15.416667                          1
# 1                                15.416667                          1
# 2                                15.416667                          1
# 3                                15.416667                          1
# 4                                15.416667                          1
#
#    CD_ENTRE - Código de Entrevista  DATA - Data da Entrevista  ...  \
# 0                                1                    6092017  ...
# 1                                1                    6092017  ...
# 2                                1                    6092017  ...
# 3                                1                    6092017  ...
# 4                                1                    6092017  ...
#
#    FE_PESS_2055  FE_PESS_2060  FE_VIA_2023  FE_VIA_2025  FE_VIA_2035  \
# 0     26.315479     24.390212    24.437958    25.044709    29.800155
# 1           NaN           NaN    24.437958    25.044709    29.800155
# 2     13.454352     13.064974    18.236548    17.616991    17.109920
# 3           NaN           NaN    18.236548    17.616991    17.109920
# 4           NaN           NaN    18.236548    17.616991    17.109920
#
#    FE_VIA_2040  FE_VIA_2045  FE_VIA_2050  FE_VIA_2055  FE_VIA_2060
# 0    32.189376    31.791907    29.625860    29.818914    27.637332
# 1    32.189376    31.791907    29.625860    29.818914    27.637332
# 2    17.086364    16.539373    15.823226    15.245559    14.804342
# 3    17.086364    16.539373    15.823226    15.245559    14.804342
# 4    17.086364    16.539373    15.823226    15.245559    14.804342
#
# [5 rows x 260 columns]
