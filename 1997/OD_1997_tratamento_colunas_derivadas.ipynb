# %%
import pandas as pd

# %%
ano = 1997
file_name = f'OD_{ano}.csv'
df = pd.read_csv(file_name)
df.info()

# %%
df.head()

# %%
campo_de = 'F_DOM'
campo_para = 'Identifica Primeiro Registro do Domicílio'
tipos = {
    0: 'Demais Registros',
    1: 'Primeiro Registro do Domicílio'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'TIPO_DOM'
campo_para = 'Tipo de Domicílio'
tipos = {
    1: 'Particular',
    2: 'Coletivo',
    3: 'Favela'   
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'RESULDOM'
campo_para = 'Resultado do Domicílio'
tipos = {
    6: 'Completa sem Viagem',
    7: 'Completa com Viagem'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'F_FAM'
campo_para = 'Identifica Primeiro Registro da Família'
tipos = {
    0: 'Demais Registros',
    1: 'Primeiro Registro da Família'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'RESULFAM'
campo_para = 'Resultado da Família'
tipos = {
    6: 'Completa sem Viagem',
    7: 'Completa com Viagem'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'CONDMORA'
campo_para = 'Condição de Moradia'
tipos = {
    1: 'Alugada',
    2: 'Própria',
    3: 'Cedida',
    4: 'Outros',
    5: 'Não Respondeu'
}
df[campo_para] = df[campo_de].map(tipos)

    
campo_de = 'DIA_SEMA'
campo_para = 'Dia da Semana'
tipos = {
    2: 'Segunda-feira',
    3: 'Terça-feira',
    4: 'Quarta-feira',
    5: 'Quinta-feira',
    6: 'Sexta-feira'
}
df[campo_para] = df[campo_de].map(tipos)
    


campo_de = 'CD_RENFA'
campo_para = 'Código de Renda Familiar Mensal'
tipos = {
    1: 'Renda Familiar Completa',
    2: 'Não Tem Renda',
    3: 'Renda Familiar Incompleta'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'ABIPEME'
campo_para = 'Classificação ABIPEME'
tipos = {
    1: 'A',
    2: 'B',
    3: 'C',
    4: 'D',
    5: 'E'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'F_PESS'
campo_para = 'Identifica Primeiro Registro da Pessoa'
tipos = {
    0: 'Demais registros',
    1: 'Primeiro registro da pessoa'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'SIT_FAM'
campo_para = 'Situação Familiar'
tipos = {
    1: 'Chefe',
    2: 'Cônjuge',
    3: 'Filho(a)',
    4: 'Parente/Agregado',
    5: 'Empregado Residente',
    6: 'Visitante não Residente na RMSP'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'SEXO'
campo_para = 'Sexo'
tipos = {
    1: 'Masculino',
    2: 'Feminino',
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'SE_ESTUD'
campo_para = 'Estuda Atualmente?'
tipos = {
    1: 'Não',
    2: 'Creche/Pré-Escola',
    3: '1o./2o./3o. Graus',
    4: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'GRAU_INS'
campo_para = 'Grau de Instrução'
tipos = {
    1: 'Não-alfabetizado',
    2: 'Pré-Escola',
    3: '1o. Grau Incompleto',
    4: '1o. Grau Completo',
    5: '2o. Grau Incompleto',
    6: '2o. Grau Completo',
    7: 'Superior Incompleto',
    8: 'Superior Completo'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'CD_ATIVI'
campo_para = 'Condição de Atividade'
tipos = {
    1: 'Ocupado',
    2: 'Ocupado Eventualmente',
    3: 'Em Licença',
    4: 'Não Ocupado',
    5: 'Aposentado/Pensionista',
    6: 'Nunca Trabalhou',
    7: 'Dona de Casa',
    8: 'Estudante'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'OCUP_PRI'
campo_para = 'Ocupação Principal'
tipos = {
    1: 'Assalariado com Carteira',
    2: 'Assalariado sem Carteira',
    3: 'Funcionário Público',
    4: 'Autônomo',
    5: 'Empregador',
    6: 'Profissional Liberal',
    7: 'Trab. Doméstico com Carteira',
    8: 'Trab. Doméstico sem Carteira',
    9: 'Dono de Negócio Familiar',
    10: 'Trabalhador Familiar',
    11: 'Não se Aplica'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'SET_ATIV'
campo_para = 'Setor de Atividade'
tipos = {
    1: 'Agrícola',
    2: 'Construção Civil',
    3: 'Indústria',
    4: 'Comércio',
    5: 'Serviços de Transp. Carga',
    6: 'Serviços de Transp. de Passag.',
    7: 'Serviços Creditícios/Financeiros',
    8: 'Serviços Pessoais',
    9: 'Serviços de Alimentação',
    10: 'Serviços de Saúde',
    11: 'Serviços de Educação',
    12: 'Serviços Especializados',
    13: 'Serviços da Adm. Pública',
    14: 'Outros',
    15: 'Não se Aplica'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'CO_REN_I'
campo_para = 'Condição de Renda Individual'
tipos = {
    1: 'Tem Renda',
    2: 'Não Tem Renda',
    3: 'Não Respondeu'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'USA_VTRA'
campo_para = 'Usa Vale-Transporte ?'
tipos = {
    1: 'Sim',
    2: 'Não'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'MOTIVO_O'
campo_para = 'Motivo na Origem'
tipos = {    
    1: 'Trabalho Indústria',
    2: 'Trabalho Comércio',
    3: 'Trabalho Serviços',
    4: 'Escola/Educação',
    5: 'Compras',
    6: 'Médico/Dentista/Saúde',
    7: 'Recreação/Visitas',
    8: 'Residência',
    9: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)
    

campo_de = 'MOTIVO_D'
campo_para = 'Motivo no Destino'
tipos = {
    1: 'Trabalho Indústria',
    2: 'Trabalho Comércio',
    3: 'Trabalho Serviços',
    4: 'Escola/Educação',
    5: 'Compras',
    6: 'Médico/Dentista/Saúde',
    7: 'Recreação/Visitas',
    8: 'Residência',
    9: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'SERVIR_O'
campo_para = 'Servir Passageiro na Origem'
tipos = {
    1: 'Sim',
    2: 'Não'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'SERVIR_D'
campo_para = 'Servir Passageiro no Destino'
tipos = {
    1: 'Sim',
    2: 'Não'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'MODO1'
campo_para = 'Modo 1'
tipos = {
    1: 'Ônibus',
    2: 'Ônibus Fretado',
    3: 'Transporte Escolar',
    4: 'Dirigindo Automóvel',
    5: 'Passageiro de Automóvel',
    6: 'Táxi',
    7: 'Lotação/Perua',
    8: 'Metrô',
    9: 'Trem',
    10: 'Moto',
    11: 'Bicicleta',
    12: 'A Pé',
    13: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'MODO2'
campo_para = 'Modo 2'
tipos = {
    1: 'Ônibus',
    2: 'Ônibus Fretado',
    3: 'Transporte Escolar',
    4: 'Dirigindo Automóvel',
    5: 'Passageiro de Automóvel',
    6: 'Táxi',
    7: 'Lotação/Perua',
    8: 'Metrô',
    9: 'Trem',
    10: 'Moto',
    11: 'Bicicleta',
    12: 'A Pé',
    13: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'MODO3'
campo_para = 'Modo 3'
tipos = {
    1: 'Ônibus',
    2: 'Ônibus Fretado',
    3: 'Transporte Escolar',
    4: 'Dirigindo Automóvel',
    5: 'Passageiro de Automóvel',
    6: 'Táxi',
    7: 'Lotação/Perua',
    8: 'Metrô',
    9: 'Trem',
    10: 'Moto',
    11: 'Bicicleta',
    12: 'A Pé',
    13: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'MODO4'
campo_para = 'Modo 4'
tipos = {
    1: 'Ônibus',
    2: 'Ônibus Fretado',
    3: 'Transporte Escolar',
    4: 'Dirigindo Automóvel',
    5: 'Passageiro de Automóvel',
    6: 'Táxi',
    7: 'Lotação/Perua',
    8: 'Metrô',
    9: 'Trem',
    10: 'Moto',
    11: 'Bicicleta',
    12: 'A Pé',
    13: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'PQ_VIAPE'
campo_para = 'Motivo da Viagem a Pé'
tipos = {
    1: 'Condução Cara',
    2: 'Condução Desconfortável',
    3: 'Ponto/Estação Distante',
    4: 'Condução Demora a Passar',
    5: 'Condução Lotada',
    6: 'Viagem Demorada',
    7: 'Horário Irregular ( da condução)',
    8: 'Pequena Distância',
    9: 'Outros Motivos'
}
df[campo_para] = df[campo_de].map(tipos)


campo_de = 'MODOPRIN'
campo_para = 'Modo Principal'
tipos = {
    1: 'Ônibus',
    2: 'Ônibus Fretado',
    3: 'Transporte Escolar',
    4: 'Dirigindo Automóvel',
    5: 'Passageiro de Automóvel',
    6: 'Táxi',
    7: 'Lotação/Perua',
    8: 'Metrô',
    9: 'Trem',
    10: 'Moto',
    11: 'Bicicleta',
    12: 'A Pé',
    13: 'Outros'
}
df[campo_para] = df[campo_de].map(tipos)

campo_de = 'TIPO_VG'
campo_para = 'Tipo de Viagem'
tipos = {
    1: 'Coletivo',
    2: 'Individual',
    3: 'A pé'
}
df[campo_para] = df[campo_de].map(tipos)

df.tail()

# %%
zonas = {
    2: 'Parque Dom Pedro',
    3: 'Praça João Mendes',
    4: 'Ladeira da Memória',
    5: 'República',
    6: 'Santa Ifigênia',
    7: 'Luz',
    19: 'Bom Retiro I',
    19: 'Bom Retiro II',
    20: 'Canindé I',
    20: 'Canindé II',
    21: 'Pari',
    22: 'Bresser I',
    22: 'Bresser II',
    22: 'Bresser III',
    8: 'Brás I',
    8: 'Brás II',
    9: 'Independência',
    10: 'Cambuci',
    11: 'Glicério',
    12: 'Aclimação I',
    12: 'Aclimação II',
    13: 'Liberdade I',
    13: 'Liberdade II',
    14: 'Bexiga I',
    14: 'Bexiga II',
    15: 'Bela Vista',
    16: 'Masp I',
    16: 'Masp II',
    17: 'Consolação I',
    17: 'Consolação II',
    17: 'Consolação III',
    36: 'Pacaembu I',
    36: 'Pacaembu II',
    18: 'Santa Cecília',
    38: 'Higienópolis',
    40: 'Barra Funda',
    23: 'Belenzinho I',
    23: 'Belenzinho II',
    24: 'Quarta Parada I',
    24: 'Quarta Parada II',
    24: 'Quarta Parada III',
    25: 'Moóca',
    26: 'Alto da Moóca',
    27: 'Parque da Moóca',
    55: 'Regente Feijó',
    53: 'Água Rasa I',
    53: 'Água Rasa II',
    30: 'Vila Mariana I',
    30: 'Vila Mariana II',
    30: 'Vila Mariana III',
    30: 'Vila Mariana IV',
    62: 'Santa Cruz',
    64: 'Vila Clementino',
    31: 'Lins de Vasconcelos I',
    31: 'Lins de Vasconcelos II',
    32: 'Paraíso',
    63: 'Bosque da Saúde',
    109: 'Miguel Estéfano',
    111: 'Planalto Paulista',
    65: 'Mirandópolis',
    66: 'Parque Ibirapuera I',
    66: 'Parque Ibirapuera II',
    116: 'Moema',
    117: 'Bandeirantes',
    67: 'Vila Nova Conceição',
    69: 'Chácara Itaim',
    121: 'Vila Olimpia I',
    121: 'Vila Olimpia II',
    123: 'Brooklin',
    124: 'Vila Cordeiro',
    122: 'Berrini',
    33: 'Pamplona I',
    33: 'Pamplona II',
    68: 'Jardins',
    35: 'Clínicas',
    34: 'Trianon I',
    34: 'Trianon II',
    71: 'Jardim Paulistano',
    70: 'Jardim Europa',
    72: 'Pinheiros',
    73: 'Vila Madalena',
    37: 'Cardoso de Almeida I',
    37: 'Cardoso de Almeida II',
    37: 'Cardoso de Almeida III',
    74: 'Perdizes I',
    74: 'Perdizes II',
    76: 'Pompéia I',
    76: 'Pompéia II',
    41: 'Água Branca I',
    41: 'Água Branca II',
    39: 'Sumaré I',
    39: 'Sumaré II',
    75: 'Vila Beatriz',
    130: 'Alto de Pinheiros I',
    130: 'Alto de Pinheiros II',
    79: 'Santa Marina I',
    79: 'Santa Marina II',
    77: 'Lapa',
    78: 'Vila Ipojuca I',
    78: 'Vila Ipojuca II',
    78: 'Vila Ipojuca III',
    132: 'Vila Hamburguesa I',
    132: 'Vila Hamburguesa II',
    133: 'Vila Leopoldina I',
    133: 'Vila Leopoldina II',
    133: 'Vila Leopoldina III',
    140: 'Vila Zatt',
    139: 'Pirituba',
    137: 'São Domingos',
    138: 'Jardim Mutinga',
    136: 'Jaguara',
    208: 'Jaraguá I',
    208: 'Jaraguá II',
    209: 'Parada de Taipas',
    270: 'Parque Morro Doce',
    271: 'Anhanguera',
    272: 'Perus',
    211: 'Vista Alegre',
    210: 'Jardim Damasceno',
    145: 'Vila Terezinha',
    144: 'Brasilândia',
    143: 'Vila Morro Grande',
    142: 'Itaberaba',
    141: 'Freguesia do Ó',
    44: 'Carandiru I',
    44: 'Carandiru II',
    45: 'Tietê I',
    45: 'Tietê II',
    43: 'Parque Anhembi',
    83: 'Santana',
    84: 'Santa Terezinha',
    85: 'Jardim São Paulo',
    42: 'Casa Verde',
    82: 'Parque Peruche',
    80: 'Limão',
    81: 'Casa Verde Alta',
    146: 'Cachoeirinha',
    147: 'Jardim Peri',
    212: 'Reserva da Cantareira',
    148: 'Mandaqui',
    149: 'Horto Florestal',
    213: 'ETA Guaraú',
    152: 'Pq Palmas do Tremembé',
    151: 'Tremembé',
    214: 'Cantareira',
    215: 'Jardim das Pedras',
    155: 'Jardim Guapira',
    86: 'Parada Inglesa',
    150: 'Tucuruvi',
    153: 'Vila Gustavo',
    156: 'Cohab Jova Real',
    154: 'Jaçanã',
    89: 'Parque Edu Chaves',
    87: 'Vila Medeiros',
    88: 'Jardim Brasil',
    49: 'Jardim Japão',
    50: 'Parque Novo Mundo',
    48: 'Vila Maria',
    47: 'Vila Isolina Mazzei',
    46: 'Vila Guilherme I',
    46: 'Vila Guilherme II',
    52: 'Tatuapé I',
    52: 'Tatuapé II',
    51: 'Pq São Jorge I',
    51: 'Pq São Jorge II',
    91: 'Penha',
    93: 'Tiquatira',
    164: 'Vila Esperança',
    160: 'Rui Barbosa',
    92: 'Cangaíba',
    159: 'Eng.Goulart I',
    159: 'Eng.Goulart II',
    161: 'Ermelino Matarazzo I',
    161: 'Ermelino Matarazzo II',
    218: 'Parque Buturussu',
    162: 'Ponte Rasa',
    163: 'Águia de Haia',
    219: 'Limoeiro',
    220: 'Vila Jacuí',
    226: 'Parada XV',
    227: 'Itaquera',
    223: 'Vila Campanela',
    224: 'Rio Verde',
    225: 'Saudade',
    221: 'São Miguel Paulista',
    222: 'Cidade Nitro-Operária',
    279: 'Jardim Helena',
    280: 'Jardim Romano',
    281: 'Vila Curuçá',
    284: 'Jardim Robru',
    286: 'Lajeado',
    287: 'Fabrica Bandeirantes',
    285: 'Fazenda Itaim',
    282: 'Itaim Paulista',
    283: 'Jardim das Oliveiras',
    95: 'Vila California',
    96: 'Vila Carrão',
    54: 'Jardim Anália Franco',
    97: 'Vila Formosa',
    171: 'Sapopemba',
    169: 'Aricanduva',
    94: 'Vila Matilde',
    166: 'Vila Guilhermina',
    165: 'Cidade A.E.Carvalho',
    167: 'Artur Alvim',
    168: 'Cidade Líder',
    228: 'Santa Marcelina',
    170: 'Parque Savoy',
    229: 'Vila Carmosina',
    230: 'Fazenda Caguaçu',
    231: 'Parque do Carmo',
    292: 'Gleba do Pessêgo',
    289: 'José Bonifácio',
    290: 'Guaianases',
    291: 'Juscelino Kubitschek',
    293: 'Cidade Tiradentes',
    295: 'Terceira Divisão',
    294: 'Iguatemi',
    296: 'Parque São Rafael',
    236: 'Rodolfo Pirani',
    58: 'Ipiranga I',
    58: 'Ipiranga II',
    59: 'Nazaré I',
    59: 'Nazaré II',
    29: 'Vila Monumento',
    28: 'Vila Independência',
    101: 'Vila Carioca',
    103: 'Moinho Velho',
    104: 'São João Clímaco',
    106: 'Sacomã',
    108: 'Parque do Estado',
    107: 'Vila Moraes',
    61: 'Jardim da Saúde I',
    61: 'Jardim da Saúde II',
    60: 'Jardim Previdência',
    57: 'Quinta Parada',
    56: 'Orfanato',
    100: 'Vila Zelina',
    99: 'Linhas Corrente',
    98: 'Vila Ema',
    175: 'Parque São Lucas',
    176: 'Parque Sta Madalena',
    173: 'Jardim Colorado',
    174: 'Teotêonio Vilela',
    235: 'Fazenda da Juta',
    233: 'São Mateus',
    172: 'Cidade IV Centenário',
    232: 'Rio Claro',
    234: 'Cidade Satélite',
    120: 'Joaquim Nabuco',
    119: 'Vieira de Moraes',
    118: 'Campo Belo',
    112: 'Congonhas',
    114: 'Jardim Aeroporto',
    115: 'Vila Santa Catarina',
    113: 'Jabaquara',
    110: 'Cidade Vargas',
    182: 'Jardim Bom Clima',
    185: 'Cupecê',
    183: 'Jardim Miriam',
    184: 'Vila Missionária',
    189: 'Jurubatuba',
    188: 'Vila São Pedro',
    186: 'Campo Grande',
    187: 'Vila Sabará',
    245: 'Mar Paulista',
    244: 'Pedreira',
    250: 'Vila Socorro',
    248: 'Parque Interlagos',
    249: 'Jardim Represa',
    247: 'Rio Bonito',
    246: 'SESC Interlagos',
    303: 'Jardim Presidente',
    302: 'Grajaú',
    301: 'Cocaia',
    347: 'Bororé',
    349: 'Jaceguava',
    348: 'Parelheiros',
    382: 'Marsilac',
    193: 'Granja Julieta',
    190: 'Chácara Flora',
    191: 'Santo Amaro',
    192: 'Vila Miranda',
    254: 'Jardim São Luís',
    252: 'Centro Empresarial',
    251: 'Guarapiranga',
    304: 'Jardim Capela',
    305: 'Riviera',
    306: "M' Boi Mirim",
    253: 'Jardim Ângela',
    255: 'Capão Redondo',
    307: 'Adventista',
    308: 'Parque Fernanda',
    127: 'Morumbi',
    126: 'Joquei Clube',
    125: 'Fazenda Morumbi',
    128: 'Real Parque',
    194: 'Paraisópolis',
    195: 'Jardim Vitória Régia',
    196: 'Vila Suzana',
    256: 'Parque Arariba',
    259: 'Jardim Mitsutani',
    258: 'Pirajussara',
    257: 'Jardim Umarizal',
    197: 'Portal do Morumbi',
    198: 'Vila Sônia I',
    198: 'Vila Sônia II',
    200: 'Jardim Maria do Carmo',
    262: 'Jardim Cambará',
    263: 'Jardim João XXIII',
    264: 'Raposo Tavares',
    201: 'Rio Pequeno',
    202: 'Jardim Adalgiza',
    135: 'Parque Continental',
    134: 'Jaguaré',
    131: 'Cidade Universitária',
    129: 'Jardim Caxingui I',
    129: 'Jardim Caxingui II',
    199: 'Jardim Bonfiglioli',
    273: 'Melhoramentos',
    324: 'Caieiras',
    323: 'Santa Inês',
    322: 'Cajamar',
    358: 'Anhanguera',
    359: 'Cristais',
    325: 'Franco da Rocha',
    363: 'Juqueri',
    360: 'Sete Voltas',
    361: 'Francisco Morato',
    362: 'Cascatas',
    326: 'Mairiporã',
    274: 'Paiva Castro',
    364: 'Colinas',
    365: 'Pirucaia',
    158: 'Guarulhos',
    90: 'Rod.Presidente Dutra I',
    90: 'Rod.Presidente Dutra II',
    90: 'Rod.Presidente Dutra III',
    157: 'Vila Galvão I',
    157: 'Vila Galvão II',
    217: 'Jardim América',
    277: 'Cumbica',
    278: 'Pimentas',
    216: 'Picanço',
    275: 'Morro dos Macacos',
    276: 'Estr.de Nazaré Paulista',
    366: 'Vasconcelândia',
    327: 'Arujazinho',
    328: 'Arujá',
    330: 'Fazenda Velha',
    368: 'Santa Isabel',
    367: 'Jaguari',
    336: 'Ferraz de Vasconcelos',
    340: 'Paiol Velho',
    288: 'Santos Dumont',
    337: 'Jardim São José',
    334: 'Poá',
    331: 'Itaquaquecetuba',
    329: 'Bonsucesso',
    332: 'Pinheirinho',
    335: 'Miguel Badra',
    338: 'Suzano',
    341: 'Ouro Fino I',
    341: 'Ouro Fino II',
    372: 'Mogi das Cruzes I',
    372: 'Mogi das Cruzes II',
    375: 'Mogi das Cruzes III',
    371: 'Brás Cubas',
    339: 'Jundiapeba',
    333: 'Jd. Graziella',
    369: 'Itapeti',
    374: 'Sabaúna',
    373: 'César de Souza',
    375: 'Reservatório de Jundiaí',
    376: 'Biritiba Mirim',
    377: 'Salesópolis',
    370: 'Guararema',
    105: 'Boa Vista',
    178: 'Vila Gerti',
    102: 'São Caetano do Sul I',
    102: 'São Caetano do Sul II',
    179: 'Santo André I',
    179: 'Santo André II',
    177: 'Utinga I',
    177: 'Utinga II',
    177: 'Utinga III',
    237: 'Parque das Nações',
    239: 'Jardim do Estádio',
    298: 'Parque do Pedroso',
    380: 'Paranapiacaba',
    238: 'Capuava',
    297: 'Mauá I',
    297: 'Mauá II',
    342: 'Vista Alegre',
    345: 'Ribeirão Pires',
    343: 'Jardim Santa Luzia',
    344: 'Ouro Fino Paulista',
    378: 'Parque Sete Pontes',
    379: 'Rio Grande da Serra',
    241: 'Planalto',
    180: 'Rudge Ramos',
    240: 'São Bernardo do Campo',
    299: 'Demarchi',
    346: 'Riacho Grande I',
    381: 'Caminho do Mar',
    300: 'Reservatório Billings',
    181: 'Diadema',
    242: 'Piraporinha',
    243: 'Eldorado',
    260: 'Taboão',
    261: 'Parque Pinheiros',
    309: 'Santo Eduardo',
    310: 'Embu',
    311: 'Ressaca',
    351: 'Itapecerica da Serra',
    352: 'Jardim Petrópolis',
    353: 'Embu-Mirim',
    384: 'São Lourenço da Serra',
    350: 'Embu-Guaçu',
    383: 'Cipó I',
    383: 'Cipó II',
    385: 'Juquitiba',
    319: 'Barueri',
    269: 'Aphaville',
    268: 'Tamboré',
    317: 'Quitaúna',
    315: 'Jardim Silveira I',
    315: 'Jardim Silveira II',
    315: 'Jardim Silveira III',
    320: 'Jardim Belval',
    267: 'Carapicuíba I',
    267: 'Carapicuíba II',
    313: 'Aldeia da Carapicuíba I',
    313: 'Aldeia da Carapicuíba II',
    204: 'Osasco I',
    204: 'Osasco II',
    203: 'Santo Antonio I',
    203: 'Santo Antonio II',
    265: 'Jardim das Flores',
    266: 'Jardim Veloso I',
    266: 'Jardim Veloso II',
    205: 'Jardim Piratininga I',
    205: 'Jardim Piratininga II',
    206: 'Mutinga I',
    206: 'Mutinga II',
    207: 'Três Montanhas',
    318: 'Ribeirão Itaqui',
    316: 'Jandira',
    314: 'Ribeirão das Pombas',
    312: 'Granja Viana',
    355: 'Cotia',
    354: 'Capueira',
    386: 'Caucaia',
    387: 'Caucaia do Alto',
    388: 'Vargem Grande Paulista',
    389: 'Quatro Encruzilhadas',
    356: 'Itapevi',
    321: 'Santana de Parnaíba',
    357: 'Pirapora do Bom Jesus',
    999: 'Zona Externa'
}

campo_de = 'ZONAESC'
campo_para = 'Zona da Escola'
df[campo_para] = df[campo_de].map(zonas)

campo_de = 'ZONA_D'
campo_para = 'Zona de Destino'
df[campo_para] = df[campo_de].map(zonas)

campo_de = 'ZONA_O'
campo_para = 'Zona de Origem'
df[campo_para] = df[campo_de].map(zonas)

campo_de = 'ZONA'
campo_para = 'Zona do Domicílio'
df[campo_para] = df[campo_de].map(zonas)

campo_de = 'ZONATRA1'
campo_para = 'Zona do Primeiro Trabalho'
df[campo_para] = df[campo_de].map(zonas)

campo_de = 'ZONATRA2'
campo_para = 'Zona do Segundo Trabalho'
df[campo_para] = df[campo_de].map(zonas)

df[[
    'ZONAESC',
    'Zona da Escola',
    'ZONA_D',
    'Zona de Destino',
    'ZONA_O',
    'Zona de Origem',
    'ZONA',
    'Zona do Domicílio',
    'ZONATRA1',
    'Zona do Primeiro Trabalho',
    'ZONATRA2', 
    'Zona do Segundo Trabalho'
]]

# %%
municipios = {
    1 :'Arujá',
    2 :'Barueri',
    3 :'Biritiba-Mirim',
    4 :'Caieiras',
    5 :'Cajamar',
    6 :'Carapicuíba',
    7 :'Cotia',
    8 :'Diadema',
    9 :'Embu',
    10 :'Embu-Guaçu',
    11 :'Ferraz de Vasconcelos',
    12 :'Francisco Morato',
    13 :'Franco da Rocha',
    14 :'Guararema',
    15 :'Guarulhos',
    16 :'Itapecerica da Serra',
    17 :'Itapevi',
    18 :'Itaquaquecetuba',
    19 :'Jandira',
    20 :'Juquitiba',
    21 :'Mairiporã',
    22 :'Mauá',
    23 :'Mogi das Cruzes',
    24 :'Osasco',
    25 :'Pirapora do Bom Jesus',
    26 :'Poá',
    27 :'Ribeirão Pires',
    28 :'Rio Grande da Serra',
    29 :'Salesópolis',
    30 :'Santa Isabel',
    31 :'Santana do Parnaíba',
    32 :'Santo André',
    33 :'São Bernardo do Campo',
    34 :'São Caetano do Sul',
    35 :'São Lourenço da Serra',
    36 :'São Paulo',
    37 :'Suzano',
    38 :'Taboão da Serra',
    39 :'Vargem Grande Paulista',
    99: 'Munício Externo'
}

campo_de = 'MUNIESC'
campo_para = 'Município da Escola'
df[campo_para] = df[campo_de].map(municipios)

campo_de = 'MUNIDEST'
campo_para = 'Município de Destino'
df[campo_para] = df[campo_de].map(municipios)

campo_de = 'MUNIORIG'
campo_para = 'Município de Origem'
df[campo_para] = df[campo_de].map(municipios)

campo_de = 'MUNI_DOM'
campo_para = 'Município do Domicílio'
df[campo_para] = df[campo_de].map(municipios)

campo_de = 'MUNITRA1'
campo_para = 'Município do Primeiro Trabalho'
df[campo_para] = df[campo_de].map(municipios)

campo_de = 'MUNTRA2'
campo_para = 'Município do Segundo Trabalho'
df[campo_para] = df[campo_de].map(municipios)


df[[
    'MUNIESC',
    'Município da Escola',
    'MUNIDEST',
    'Município de Destino',
    'MUNIORIG',
    'Município de Origem',
    'MUNI_DOM',
    'Município do Domicílio',
    'MUNITRA1',
    'Município do Primeiro Trabalho',
    'MUNTRA2',
    'Município do Segundo Trabalho'
]]

# %%
df_renomeado = df.rename(columns={
    'ZONA': 'ZONA - Zona do Domicílio',
    'MUNI_DOM': 'MUNI_DOM - Município de Domicílio',
    'CO_DOM_X': 'CO_DOM_X - Coordenada X Domicílio',
    'CO_DOM_Y': 'CO_DOM_Y - Coordenada Y Domicílio',
    'ID_DOM': 'ID_DOM - Identifica Domicílio',
    'F_DOM': 'F_DOM - Identifica Primeiro Registro do Domicílio',
    'FE_DOM': 'FE_DOM - Fator de Expansão do Domicílio',
    'DOM': 'DOM - Número do Domicílio',
    'CD_ENTRE': 'CD_ENTRE - Código de Entrevista',
    'DATA': 'DATA - Data da Entrevista',
    'TIPO_DOM': 'TIPO_DOM - Tipo de Domicílio',
    'AGUA': 'AGUA - Possui água encanada?',
    'RUA_PAVI': 'RUA_PAVI - A rua é pavimentada?',
    'NO_MORAD': 'NO_MORAD - Total de Moradores no Domicílio',
    'TOT_FAM': 'TOT_FAM - Total de Familias no Domicílio',
    'ID_FAM': 'ID_FAM - Identifica Família',
    'F_FAM': 'F_FAM - Identifica Primeiro Registro da Família',
    'FE_FAM': 'FE_FAM - Fator de Expansão da Família',
    'FAMILIA': 'FAMILIA - Número da Família',
    'NO_MORAF': 'NO_MORAF - Total de Moradores na Família',
    'CONDMORA': 'CONDMORA - Condição de Moradia',
    'QT_BANHO': 'QT_BANHO - Banheiros',
    'QT_EMPRE': 'QT_EMPRE - Empregados Domésticos',
    'QT_AUTO': 'QT_AUTO - Automóveis',
    'QT_MICRO': 'QT_MICRO - Microcomputadores',
    'QT_LAVALOU': 'QT_LAVALOU - Máquinas de Lava louças',
    'QT_GEL1': 'QT_GEL1 - Geladeiras de uma porta',
    'QT_GEL2': 'QT_GEL2 - Geladeiras de duas portas',
    'QT_FREEZ': 'QT_FREEZ - Freezers',
    'QT_MLAVA': 'QT_MLAVA - Máquinas de Lavar roupa',
    'QT_DVD': 'QT_DVD - DVDs',
    'QT_MICROON': 'QT_MICROON - Microondas',
    'QT_MOTO': 'QT_MOTO - Motos',
    'QT_SECAROU': 'QT_SECAROU - Secadora de roupas',
    'QT_BICICLE': 'QT_BICICLE - Bicicletas',
    'NAO_DCL_IT': 'NAO_DCL_IT - Código de Declaração de Itens de Conforto',
    'CRITERIOBR': 'CRITERIOBR - Critério de Classificação Econômica Brasil',
    'PONTO_BR': 'PONTO_BR - Pontos Critério Brasil',
    'ANO_AUTO1': 'ANO_AUTO1 - Ano Fabricação do Auto 1',
    'ANO_AUTO2': 'ANO_AUTO2 - Ano Fabricação do Auto 2',
    'ANO_AUTO3': 'ANO_AUTO3 - Ano Fabricação do Auto 3',
    'RENDA_FA': 'RENDA_FA - Renda Familiar Mensal',
    'CD_RENFA': 'CD_RENFA - Código de Renda Familiar Mensal',
    'ID_PESS': 'ID_PESS - Identifica Pessoa',
    'F_PESS': 'F_PESS - Identifica Primeiro Registro da Pessoa',
    'FE_PESS': 'FE_PESS - Fator de Expansão da Pessoa',
    'PESSOA': 'PESSOA - Número da Pessoa',
    'SIT_FAM': 'SIT_FAM - Situação Familiar',
    'IDADE': 'IDADE - Idade',
    'SEXO': 'SEXO - Sexo',
    'ESTUDA': 'ESTUDA - Estuda Atualmente?',
    'GRAU_INS': 'GRAU_INS - Grau de Instrução',
    'CD_ATIVI': 'CD_ATIVI - Condição de Atividade',
    'CO_REN_I': 'CO_REN_I - Condição de Renda Individual',
    'VL_REN_I': 'VL_REN_I - Renda Individual',
    'ZONA_ESC': 'ZONA_ESC - Zona da Escola',
    'MUNIESC': 'MUNIESC - Município da Escola',
    'CO_ESC_X': 'CO_ESC_X - Coordenada X Escola',
    'CO_ESC_Y': 'CO_ESC_Y - Coordenada Y Escola',
    'TIPO_ESC': 'TIPO_ESC - Tipo de Escola',
    'ZONATRA1': 'ZONATRA1 - Zona do Primeiro Trabalho',
    'MUNITRA1': 'MUNITRA1 - Município do Primeiro Trabalho',
    'CO_TR1_X': 'CO_TR1_X - Coordenada X 1º Trabalho',
    'CO_TR1_Y': 'CO_TR1_Y - Coordenada Y 1º Trabalho',
    'TRAB1_RE': 'TRAB1_RE - Primeiro Trabalho é igual a Residência ?',
    'TRABEXT1': 'TRABEXT1 - Realiza Trabalho Externo-1º Trabalho',
    'OCUP1': 'OCUP1 - Ocupação do 1º Trabalho',
    'SETOR1': 'SETOR1 - Setor de Atividade do 1º Trabalho',
    'VINC1': 'VINC1 - Vínculo Empregatício do 1º Trabalho',
    'ZONATRA2': 'ZONATRA2 - Zona do 2º Trabalho',
    'MUNITRA2': 'MUNITRA2 - Município do 2º Trabalho',
    'CO_TR2_X': 'CO_TR2_X - Coordenada X 2º Trabalho',
    'CO_TR2_Y': 'CO_TR2_Y - Coordenada Y 2º Trabalho',
    'TRAB2_RE': 'TRAB2_RE - Segundo Trabalho é igual a Residência ?',
    'TRABEXT2': 'TRABEXT2 - Realiza Trabalho Externo-2º Trabalho',
    'OCUP2': 'OCUP2 - Ocupação do 2º Trabalho',
    'SETOR2': 'SETOR2 - Setor de Atividade do 2º Trabalho',
    'VINC2': 'VINC2 - Vínculo Empregatício do 2º Trabalho',
    'N_VIAG': 'N_VIAG - Número da Viagem',
    'FE_VIA': 'FE_VIA - Fator de Expansão da Viagem',
    'DIA_SEM': 'DIA_SEM - Dia da Semana',
    'TOT_VIAG': 'TOT_VIAG - Total de Viagens da Pessoa',
    'ZONA_O': 'ZONA_O - Zona de Origem',
    'MUNI_O': 'MUNI_O - Município de Origem',
    'CO_O_X': 'CO_O_X - Coordenada X Origem',
    'CO_O_Y': 'CO_O_Y - Coordenada Y Origem',
    'ZONA_D': 'ZONA_D - Zona de Destino',
    'MUNI_D': 'MUNI_D - Município de Destino',
    'CO_D_X': 'CO_D_X - Coordenada X Destino',
    'CO_D_Y': 'CO_D_Y - Coordenada Y Destino',
    'ZONA_T1': 'ZONA_T1 - Zona da 1ª Transferência',
    'MUNI_T1': 'MUNI_T1 - Município 1ª Transferência',
    'CO_T1_X': 'CO_T1_X - Coordenada X 1ª Transferência',
    'CO_T1_Y': 'CO_T1_Y - Coordenada Y 1ª Transferência',
    'ZONA_T2': 'ZONA_T2 - Zona da 2ª Transferência',
    'MUNI_T2': 'MUNI_T2 - Município 2ª Transferência',
    'CO_T2_X': 'CO_T2_X - Coordenada X 2ª Transferência',
    'CO_T2_Y': 'CO_T2_Y - Coordenada Y 2ª Transferência',
    'ZONA_T3': 'ZONA_T3 - Zona da 3ª Transferência',
    'MUNI_T3': 'MUNI_T3 - Município 3ª Transferência',
    'CO_T3_X': 'CO_T3_X - Coordenada X 3ª Transferência',
    'CO_T3_Y': 'CO_T3_Y - Coordenada Y 3ª Transferência',
    'MOTIVO_O': 'MOTIVO_O - Motivo na Origem',
    'MOTIVO_D': 'MOTIVO_D - Motivo no Destino',
    'MOT_SRES': 'MOT_SRES - Motivo no Destino sem Residência',
    'SERVIR_O': 'SERVIR_O - Servir Passageiro na Origem',
    'SERVIR_D': 'SERVIR_D - Servir Passageiro no Destino',
    'MODO1': 'MODO1 - Modo 1',
    'MODO2': 'MODO1 - Modo 2',
    'MODO3': 'MODO1 - Modo 3',
    'MODO4': 'MODO1 - Modo 4',
    'H_SAIDA': 'H_SAIDA - Hora de Saída',
    'MIN_SAIDA': 'MIN_SAIDA - Minuto de Saída',
    'ANDA_O': 'ANDA_O - Tempo Andando na Origem',
    'H_CHEG': 'H_CHEG - Hora de Chegada',
    'MIN_CHEG': 'MIN_CHEG - Minuto de Chegada',
    'ANDA_D': 'ANDA_D - Tempo Andando no Destino',
    'DURACAO': 'DURACAO - Duração da Viagem (em minutos)',
    'MODOPRIN': 'MODOPRIN - Modo Principal',
    'TIPVG': 'TIPVG - Tipo de Viagem',
    'PAG_VIAG': 'PAG_VIAG - Quem Pagou a Viagem',
    'TP_ESAUTO': 'TP_ESAUTO - Tipo de Estacionamento do Automóvel ou Moto',
    'VL_EST': 'VL_EST - Valor do Estacionamento do Automóvel ou Moto',
    'PE_BICI': 'PE_BICI - Por Que Viajou A Pé ou Bicicleta',
    'VIA_BICI': 'VIA_BICI - Se viajou de bicicleta, usou via segregada?',
    'TP_ESBICI': 'TP_ESBICI - Estacionamento Bicicleta',
    'DISTANCIA': 'DISTANCIA - Distância em metros*',
    'ID_ORDEM': 'ID_ORDEM - Número de Ordem do Registro',
})
df_renomeado.columns

# %%
df_renomeado.head()

# %%
df['AA_PESQUISA'] = ano
df_renomeado.to_excel(f'OD_{ano}.xlsx', index=False)
print('Arquivo salvo com sucesso', f'od_{ano}.xlsx')
